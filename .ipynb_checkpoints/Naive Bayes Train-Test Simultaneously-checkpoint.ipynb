# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as sc
import matplotlib.pyplot as plt

# %%
raw_data = pd.read_csv('../Machine Learning//DataSets//binianmalignent.csv')
raw_data.head()
raw_data.drop(['id','Unnamed: 32'],axis=1,inplace=True)
(raw_data.var())
# Out:
# radius_mean                    12.418920
# texture_mean                   18.498909
# perimeter_mean                590.440480
# area_mean                  123843.554318
# smoothness_mean                 0.000198
# compactness_mean                0.002789
# concavity_mean                  0.006355
# concave points_mean             0.001506
# symmetry_mean                   0.000752
# fractal_dimension_mean          0.000050
# radius_se                       0.076902
# texture_se                      0.304316
# perimeter_se                    4.087896
# area_se                      2069.431583
# smoothness_se                   0.000009
# compactness_se                  0.000321
# concavity_se                    0.000911
# concave points_se               0.000038
# symmetry_se                     0.000068
# fractal_dimension_se            0.000007
# radius_worst                   23.360224
# texture_worst                  37.776483
# perimeter_worst              1129.130847
# area_worst                 324167.385102
# smoothness_worst                0.000521
# compactness_worst               0.024755
# concavity_worst                 0.043524
# concave points_worst            0.004321
# symmetry_worst                  0.003828
# fractal_dimension_worst         0.000326
# dtype: float64

# %%
for i in raw_data.columns.tolist()[1:]:
    sns.distplot(raw_data[i])
    plt.show()

# %%
# 0 Mean Normalize 
raw_data.iloc[:,1:] = raw_data.iloc[:,1:] -  raw_data.iloc[:,1:].mean()  
raw_data.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean   area_mean  \
# 0         M     3.862708     -8.909649       30.830967  346.110896
# 1         M     6.442708     -1.519649       40.930967  671.110896
# 2         M     5.562708      1.960351       38.030967  548.110896
# 3         M    -2.707292      1.090351      -14.389033 -268.789104
# 4         M     6.162708     -4.949649       43.130967  642.110896
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.02204          0.173259        0.211301             0.098181
# 1         -0.01162         -0.025701       -0.001899             0.021251
# 2          0.01324          0.055559        0.108601             0.078981
# 3          0.04614          0.179559        0.152601             0.056281
# 4          0.00394          0.028459        0.109201             0.055381
#
#    symmetry_mean           ...             radius_worst  texture_worst  \
# 0       0.060738           ...                  9.11081      -8.347223
# 1       0.000038           ...                  8.72081      -2.267223
# 2       0.025738           ...                  7.30081      -0.147223
# 3       0.078538           ...                 -1.35919       0.822777
# 4      -0.000262           ...                  6.27081      -9.007223
#
#    perimeter_worst   area_worst  smoothness_worst  compactness_worst  \
# 0        77.338787  1138.416872          0.029831           0.411335
# 1        51.538787  1075.416872         -0.008569          -0.067665
# 2        45.238787   828.416872          0.012031           0.170235
# 3        -8.391213  -312.883128          0.077431           0.612035
# 4        44.938787   694.416872          0.005031          -0.049265
#
#    concavity_worst  concave points_worst  symmetry_worst  \
# 0         0.439712              0.150794        0.170024
# 1        -0.030588              0.071394       -0.015076
# 2         0.178212              0.128394        0.071224
# 3         0.414712              0.142894        0.373724
# 4         0.127812              0.047894       -0.053676
#
#    fractal_dimension_worst
# 0                 0.034954
# 1                 0.005074
# 2                 0.003634
# 3                 0.089054
# 4                -0.007166
#
# [5 rows x 31 columns]

# %%
from sklearn.decomposition import PCA
pca = PCA(5).fit(raw_data)
x = np.argmax(pca.components_,axis=1)
print(x)

a,b,c = np.linalg.svd(raw_data.cov())
print(np.argmax(a,axis=1))
print(np.argmax(a,axis=0)) # this similar to PCA components

raw_data.iloc[:,np.argmax(a,axis=0)[:5]].head()

# %%
sns.heatmap(raw_data.iloc[:,np.argmax(a,axis=0)[:5]].corr(),cmap='coolwarm',fmt='.1f',annot=True)
plt.show()

# %%
f'{np.linalg.det(raw_data.cov()):.70f}'

# %%
l = ['radius_mean','texture_mean','smoothness_mean','symmetry_mean','texture_worst']
np.linalg.det(raw_data[l].cov()) # far better if we choose only normal distrubuted

# %% [markdown]
# # The probability density function for Multivariate Normal is
# $$
# f(x)=\frac{1}{\sqrt{(2 \pi)^{k} \operatorname{det} \Sigma}} \exp \left(-\frac{1}{2}(x-\mu)^{T} \Sigma^{-1}(x-\mu)\right)
# $$
#
# where $\mu$ is the mean, $\Sigma$ the covariance matrix, and **k** is the dimension of the space where x takes values.

# %% [markdown]
# # let,  Malignent = 1 benign = 0 for representation
#
# # We assume that each observation belongs to Malignent class, so we assign each new observation to belong from malignent class. Later we calculate Posterior probability of both classes taking all observation as consider

# %%
# need to shuffling the data
raw_data = raw_data.reindex(np.random.permutation(raw_data.index))

labels = raw_data['diagnosis']
labels[labels=='M'] = 1
labels[labels=='B'] = 0

del raw_data['diagnosis']
# Out:
# C:\Users\GirrajJangid\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\GirrajJangid\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
raw_data.head()
# Out:
#      radius_mean  texture_mean  perimeter_mean    area_mean  smoothness_mean  \
# 104    -3.637292      0.000351      -24.559033  -318.789104          0.00353
# 182     1.572708      1.020351        9.230967   111.710896         -0.00039
# 461    13.292708      6.980351       94.930967  1846.110896          0.01204
# 436    -1.257292      0.250351       -9.299033  -145.689104         -0.00500
# 65      0.652708      4.650351        5.430967    13.410896          0.02084
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 104         -0.018561       -0.058849            -0.036909       0.040538
# 182         -0.016351       -0.022869             0.002971      -0.019362
# 461          0.094459        0.274701             0.119981       0.024938
# 436         -0.025511       -0.070829            -0.028019       0.004938
# 65           0.043559        0.037901             0.041371       0.014138
#
#      fractal_dimension_mean           ...             radius_worst  \
# 104                0.002012           ...                 -4.72919
# 182               -0.007308           ...                  3.84081
# 461               -0.006568           ...                 19.77081
# 436                0.000672           ...                 -1.81919
# 65                 0.003742           ...                  1.04081
#
#      texture_worst  perimeter_worst   area_worst  smoothness_worst  \
# 104      -2.367223       -33.041213  -477.783128         -0.010469
# 182       7.142777        22.038787   388.416872          0.009031
# 461       5.692777       143.938787  3373.416872          0.003331
# 436      -1.297223       -12.121213  -253.683128         -0.010969
# 65        7.712777         7.338787    44.516872          0.032431
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 104          -0.105665        -0.192318             -0.082576       -0.007476
# 182           0.100435         0.018012              0.039494        0.053624
# 461           0.171335         0.411112              0.147894       -0.025976
# 436          -0.089065        -0.200918             -0.050766        0.041224
# 65            0.087335         0.030212              0.046794        0.042024
#
#      fractal_dimension_worst
# 104                -0.008426
# 182                 0.002364
# 461                -0.009676
# 436                -0.006596
# 65                  0.005164
#
# [5 rows x 30 columns]

# %%
raw_data.head()
# Out:
#      radius_mean  texture_mean  perimeter_mean    area_mean  smoothness_mean  \
# 104    -3.637292      0.000351      -24.559033  -318.789104          0.00353
# 182     1.572708      1.020351        9.230967   111.710896         -0.00039
# 461    13.292708      6.980351       94.930967  1846.110896          0.01204
# 436    -1.257292      0.250351       -9.299033  -145.689104         -0.00500
# 65      0.652708      4.650351        5.430967    13.410896          0.02084
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 104         -0.018561       -0.058849            -0.036909       0.040538
# 182         -0.016351       -0.022869             0.002971      -0.019362
# 461          0.094459        0.274701             0.119981       0.024938
# 436         -0.025511       -0.070829            -0.028019       0.004938
# 65           0.043559        0.037901             0.041371       0.014138
#
#      fractal_dimension_mean           ...             radius_worst  \
# 104                0.002012           ...                 -4.72919
# 182               -0.007308           ...                  3.84081
# 461               -0.006568           ...                 19.77081
# 436                0.000672           ...                 -1.81919
# 65                 0.003742           ...                  1.04081
#
#      texture_worst  perimeter_worst   area_worst  smoothness_worst  \
# 104      -2.367223       -33.041213  -477.783128         -0.010469
# 182       7.142777        22.038787   388.416872          0.009031
# 461       5.692777       143.938787  3373.416872          0.003331
# 436      -1.297223       -12.121213  -253.683128         -0.010969
# 65        7.712777         7.338787    44.516872          0.032431
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 104          -0.105665        -0.192318             -0.082576       -0.007476
# 182           0.100435         0.018012              0.039494        0.053624
# 461           0.171335         0.411112              0.147894       -0.025976
# 436          -0.089065        -0.200918             -0.050766        0.041224
# 65            0.087335         0.030212              0.046794        0.042024
#
#      fractal_dimension_worst
# 104                -0.008426
# 182                 0.002364
# 461                -0.009676
# 436                -0.006596
# 65                  0.005164
#
# [5 rows x 30 columns]

# %%
labels.head()
# Out:
# 104    0
# 182    1
# 461    1
# 436    0
# 65     1
# Name: diagnosis, dtype: object

# %%
# Out:
# 357

# %%
c = np.cov(new_data.T)  # (5,5)
m = np.mean(new_data,axis=0)  #(5,)
jointPDF(new_data[0,:],m,c)

# %%
def jointPDF(data, mean , cov):
    data = np.array(data)
    mean = np.array(mean)
    cov = np.array(cov)
    a = 1 / (np.sqrt((2*np.pi)**5 * np.linalg.det(cov)))
    b = np.exp( (-1/2) * np.dot(( data - mean ).dot(np.linalg.inv(cov)), ( data - mean ).T))
    return a * b

# %%
#for i in range(10):
pred_pro = []
actua_pro = labels

prior_prob_mal = 1
prior_prob_beng = 0

likelihood_prob_malignant = jointPDF(new_data[0,:] ,training_malignent.mean(),training_malignent.cov())
        
likelihood_prob_benign = jointPDF(new_data[0,:],training_benign.mean(),training_benign.cov())
    
#posterior_prob_benign = likelihood_prob_benign / (likelihood_prob_malignant + likelihood_prob_benign)
        
#posterior_prob_malignant = likelihood_prob_malignant / (likelihood_prob_malignant + likelihood_prob_benign)

# %%
        if label_key == 'B':
            if posterior_prob_benign > 0.5 :
                correct_count += 1
        
        elif label_key == 'M':
            if posterior_prob_malignant > 0.5 :
                correct_count +=1
                
    print("\nThe correct counts are",correct_count , " out of ",i)
    p = (correct_count / i )* 100
    print("%.2f"%p,"%" ,end="")

# %%
def a():
    a = 3
print(a())
locals()

# %%
(_i98)
